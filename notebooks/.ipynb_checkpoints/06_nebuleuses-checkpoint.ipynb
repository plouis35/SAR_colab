# %% [markdown]
# # nébuleuses
# $\rightarrow$ **calcul de la température et de la densité électronique avec dérougissement à partir du décrément de Balmer**
#
# cf. TP Rennes 2016 (ngc6543)
#
# et aussi :
# - 20161006_agdra_ngc6543_hd158460_hd145454
# - 20240709_10lac_tcrb_vega_alphacep_gamcas_m57_deneb
# - 20240710_10lac_chcyg_tcrb_m16_m57_betalyr_vega_alphacep
