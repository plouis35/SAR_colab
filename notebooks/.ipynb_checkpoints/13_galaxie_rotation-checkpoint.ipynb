# %% [markdown]
# # matière noire
# $\rightarrow$ **vitesse de rotation de M31**
# - mise en évidence de la matière noire

# %%
# M31 avec DADOS 900 tt/mm 
# vitesse de rotation et mise en évidence matière noire
